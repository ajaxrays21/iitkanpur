# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaxrays21/iitkanpur/blob/master/Tensorflow_ML_CODE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
tf.__version__
# Out:
# TensorFlow 2.x selected.
# '2.0.0'

# %%
mnist = tf.keras.datasets.mnist
(x_train_orig, y_train),(x_test_orig, y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train_orig[10600], cmap='binary')

# %%
x_train, x_test = x_train_orig / 255.0, x_test_orig / 255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  #tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dense(128, activation='relu'),
  # tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.2979 - accuracy: 0.9131
# Epoch 2/5
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.1436 - accuracy: 0.9577
# Epoch 3/5
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.1071 - accuracy: 0.9678
# Epoch 4/5
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0893 - accuracy: 0.9724
# Epoch 5/5
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.0748 - accuracy: 0.9766

# %%
model.evaluate(x_test,y_test)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
import numpy as np
z = np.array(model.predict(x_test))
z.shape
# Out:
# (10000, 10)

# %%
plt.imshow(x_test[1], cmap='binary')
